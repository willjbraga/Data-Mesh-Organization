# %% [markdown]
# # Prepar Ambiente
# Este notebook é usado para instalar e preparar o ambiente no databricks

# %%
# %pip install unidecode
# %restart_python

# %%
# %load_ext autoreload
# %autoreload 2
