# %%
# !pip install sqlalchemy
# !pip install dotenv
# !pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------------------------------- - 2.6/2.8 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 31.1 MB/s  0:00:00
# ...

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

DATABASE_URL = "postgresql://postgres:rh%40datamesh@db.bpiwbiwzoybrpdjjfbyn.supabase.co:5432/postgres"

engine = create_engine(DATABASE_URL)

df = pd.read_sql("SELECT * FROM colaborador LIMIT 10;", engine)

display(df)
# Out:
#    colaborador_id                      nome        telefone data_admissao  \
# 0               1      Henrique Silva Gomes  +5521999350001    2018-09-30
# 1               2    Bruno Oliveira Almeida  +5511942570002    2018-08-10
# 2               3         Helena Costa Melo  +5511936150003    2022-08-10
# 3               4         Joao Almeida Lima  +5521968810004    2017-02-22
# 4               5     Carla Melo Nascimento  +5561922910005    2017-05-26
# 5               6        Zeca Araújo Vieira  +5511947330006    2018-02-26
# 6               7      Olivia Souza Ribeiro  +5551936640007    2019-02-12
# 7               8  Samuel Oliveira Teixeira  +5534936770008    2023-02-13
# 8               9         Thiago Costa Lima  +5511947520009    2025-06-14
# 9              10    Gustavo Gomes Oliveira  +5585961550010    2018-05-14
#
#      status tipo_vinculo                                  email  fk_cargo_id  \
# ...
