# %% [markdown]
# # Notebook legado - Ingestao Bronze
#
# Este notebook encaminha para a ingestao canonica PostgreSQL/Supabase via JDBC, com persistencia Bronze em Parquet.

# %%
# %run ./01_bronze_ingestao_postgresql
