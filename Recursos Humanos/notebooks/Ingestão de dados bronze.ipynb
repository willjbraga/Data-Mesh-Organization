# %% [markdown]
# # Notebook legado - Ingestao Bronze
#
# Este notebook foi substituido pela esteira CSV do MVP de RH. Execute o notebook canonico `01_bronze_ingestao_csv.py`.

# %%
# %run ./01_bronze_ingestao_csv
