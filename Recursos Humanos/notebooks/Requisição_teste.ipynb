# %% [markdown]
# # Notebook legado - Teste de conexao
#
# Este teste direto contra PostgreSQL/Supabase foi desativado para o MVP atual. A esteira de RH usa CSVs exportados e notebooks Databricks em Delta Lake.

# %%
print("Use 01_bronze_ingestao_csv.py para iniciar a esteira de RH por CSV.")
